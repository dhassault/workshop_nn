# %%
from bokeh.io import push_notebook, show, output_notebook
from bokeh.layouts import row
from bokeh.plotting import figure
output_notebook()
# Out:
#     <div class="bk-root">
#         <a href="http://bokeh.pydata.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="eb9dd6d5-341c-478b-8fa6-527549716863">Loading BokehJS ...</span>
#     </div>

# %%
opts = dict(plot_width=250, plot_height=250, min_border=0)

# %%
p1 = figure(**opts)
r1 = p1.circle([1,2,3], [4,5,6], size=20)

p2 = figure(**opts)
r2 = p2.circle([1,2,3], [4,5,6], size=20)

# get a handle to update the shown cell with
t = show(row(p1, p2), notebook_handle=True)
# Out:
#     <div class="bk-root">
#         <div class="bk-plotdiv" id="73bb9e38-5ed6-424b-8f82-4f57c14553a4"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     var force = false;
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined" || force === true) {
#       window._bokeh_onload_callbacks = [];
#       window._bokeh_is_loading = undefined;
#     }
#
#
#
#     if (typeof (window._bokeh_timeout) === "undefined" || force === true) {
#       window._bokeh_timeout = Date.now() + 0;
#       window._bokeh_failed_load = false;
#     }
#
#     var NB_LOAD_WARNING = {'data': {'text/html':
#        "<div style='background-color: #fdd'>\n"+
#        "<p>\n"+
#        "BokehJS does not appear to have successfully loaded. If loading BokehJS from CDN, this \n"+
#        "may be due to a slow or bad network connection. Possible fixes:\n"+
#        "</p>\n"+
#        "<ul>\n"+
#        "<li>re-rerun `output_notebook()` to attempt to load from CDN again, or</li>\n"+
#        "<li>use INLINE resources instead, as so:</li>\n"+
#        "</ul>\n"+
#        "<code>\n"+
#        "from bokeh.resources import INLINE\n"+
#        "output_notebook(resources=INLINE)\n"+
#        "</code>\n"+
#        "</div>"}};
#
#     function display_loaded() {
#       if (window.Bokeh !== undefined) {
#         var el = document.getElementById("73bb9e38-5ed6-424b-8f82-4f57c14553a4");
#         el.textContent = "BokehJS " + Bokeh.version + " successfully loaded.";
#       } else if (Date.now() < window._bokeh_timeout) {
#         setTimeout(display_loaded, 100)
#       }
#     }if ((window.Jupyter !== undefined) && Jupyter.notebook.kernel) {
#       comm_manager = Jupyter.notebook.kernel.comm_manager
#       comm_manager.register_target("f53d2309-531a-4bbc-9dd8-9cc02941d0cb", function () {});
#     }
#
#     function run_callbacks() {
#       try {
#         window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       }
#       finally {
#         delete window._bokeh_onload_callbacks
#       }
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("73bb9e38-5ed6-424b-8f82-4f57c14553a4");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid '73bb9e38-5ed6-424b-8f82-4f57c14553a4' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         (function() {
#           var fn = function() {
#             var docs_json = {"3e64826c-eca5-4222-8f4b-a71bc8c26568":{"roots":{"references":[{"attributes":{"callback":null},"id":"7a3639e4-4d96-4852-a1e5-0228e697526f","type":"DataRange1d"},{"attributes":{},"id":"605bd9d0-2cd3-4c26-b901-e411ffd4db55","type":"BasicTicker"},{"attributes":{"callback":null},"id":"64225497-7305-4e86-b768-64da0f3dd928","type":"DataRange1d"},{"attributes":{"fill_color":{"value":"#1f77b4"},"line_color":{"value":"#1f77b4"},"size":{"units":"screen","value":20},"x":{"field":"x"},"y":{"field":"y"}},"id":"1363ef63-6154-40c4-b1cb-a5e45a35412f","type":"Circle"},{"attributes":{},"id":"407f52f7-1400-440d-945b-585d8fc7263f","type":"LinearScale"},{"attributes":{"formatter":{"id":"4ad540cb-9411-40f1-9a05-2d96e7157ef4","type":"BasicTickFormatter"},"plot":{"id":"e493d6a6-eaad-47bd-9886-f469950e308e","subtype":"Figure","type":"Plot"},"ticker":{"id":"605bd9d0-2cd3-4c26-b901-e411ffd4db55","type":"BasicTicker"}},"id":"9a54d314-b4ec-4420-9c20-a5be8afcf0f7","type":"LinearAxis"},{"attributes":{},"id":"cba0ab98-d1de-41be-b823-ec9e771e04a1","type":"BasicTicker"},{"attributes":{"plot":{"id":"e493d6a6-eaad-47bd-9886-f469950e308e","subtype":"Figure","type":"Plot"},"ticker":{"id":"cba0ab98-d1de-41be-b823-ec9e771e04a1","type":"BasicTicker"}},"id":"1b3a8270-dc53-43bd-bec4-b521d2c12331","type":"Grid"},{"attributes":{"dimension":1,"plot":{"id":"e493d6a6-eaad-47bd-9886-f469950e308e","subtype":"Figure","type":"Plot"},"ticker":{"id":"605bd9d0-2cd3-4c26-b901-e411ffd4db55","type":"BasicTicker"}},"id":"24433ed8-4c5b-40ed-8c13-671dac5a8e06","type":"Grid"},{"attributes":{"bottom_units":"screen","fill_alpha":{"value":0.5},"fill_color":{"value":"lightgrey"},"left_units":"screen","level":"overlay","line_alpha":{"value":1.0},"line_color":{"value":"black"},"line_dash":[4,4],"line_width":{"value":2},"plot":null,"render_mode":"css","right_units":"screen","top_units":"screen"},"id":"51fa1ad7-a429-4c71-99e3-324b68438c0d","type":"BoxAnnotation"},{"attributes":{},"id":"4ad540cb-9411-40f1-9a05-2d96e7157ef4","type":"BasicTickFormatter"},{"attributes":{"plot":{"id":"e493d6a6-eaad-47bd-9886-f469950e308e","subtype":"Figure","type":"Plot"}},"id":"2d2d9fe8-57b9-49a9-9ee9-9c5000033d18","type":"PanTool"},{"attributes":{"plot":null,"text":""},"id":"2dc00827-45bf-4f1f-941c-a9795787f1c8","type":"Title"},{"attributes":{"plot":{"id":"e493d6a6-eaad-47bd-9886-f469950e308e","subtype":"Figure","type":"Plot"}},"id":"6559d8ed-ebc4-4173-a5a9-3efbc44e3ea4","type":"WheelZoomTool"},{"attributes":{},"id":"990f11cd-a45a-4462-b82c-eaef7e41eee5","type":"BasicTickFormatter"},{"attributes":{"overlay":{"id":"51fa1ad7-a429-4c71-99e3-324b68438c0d","type":"BoxAnnotation"},"plot":{"id":"e493d6a6-eaad-47bd-9886-f469950e308e","subtype":"Figure","type":"Plot"}},"id":"4ef37617-b9db-44e2-822f-f42b127c60cf","type":"BoxZoomTool"},{"attributes":{"plot":{"id":"e493d6a6-eaad-47bd-9886-f469950e308e","subtype":"Figure","type":"Plot"}},"id":"55eb5418-6230-41e3-b360-860fb56f7b7e","type":"SaveTool"},{"attributes":{"plot":{"id":"e493d6a6-eaad-47bd-9886-f469950e308e","subtype":"Figure","type":"Plot"}},"id":"87f5108b-7444-4ced-a47b-38146eebffec","type":"ResetTool"},{"attributes":{"plot":{"id":"e493d6a6-eaad-47bd-9886-f469950e308e","subtype":"Figure","type":"Plot"}},"id":"893e765f-8595-40c5-aebb-05da7e527bc4","type":"HelpTool"},{"attributes":{},"id":"c8fd7e5c-883b-4c48-90d4-48ef3aaba4f1","type":"BasicTickFormatter"},{"attributes":{"data_source":{"id":"8842315a-b53b-4ea7-bb0d-9bb3bd9a6391","type":"ColumnDataSource"},"glyph":{"id":"ebf00516-a503-4345-9f06-1c446d71614a","type":"Circle"},"hover_glyph":null,"muted_glyph":null,"nonselection_glyph":{"id":"34c8664e-843d-4b56-939f-498babf81122","type":"Circle"},"selection_glyph":null},"id":"a3481070-a305-4fb2-953e-b5b188058aea","type":"GlyphRenderer"},{"attributes":{"callback":null,"column_names":["x","y"],"data":{"x":[1,2,3],"y":[4,5,6]}},"id":"8842315a-b53b-4ea7-bb0d-9bb3bd9a6391","type":"ColumnDataSource"},{"attributes":{"callback":null},"id":"29c30191-6900-4 ...

# %%
# the comms handle repr show what cell it can be used to update
t
# Out:
# <p><code>&lt;Bokeh Notebook handle for <strong>In[3]</strong>&gt;</code></p>

# %%
# this will update the left plot circle color with an explicit handle
r1.glyph.fill_color = "white"
push_notebook(handle=t)

# %%
# and this will update the right plot circle color because it was in the last shown cell
r2.glyph.fill_color = "pink"
push_notebook()

# %%
p3 = figure(**opts)
r3 = p3.circle([1,2,3], [4,5,6], size=20)

# get a handle to update the shown cell with
t2 = show(p3, notebook_handle=True)
# Out:
#     <div class="bk-root">
#         <div class="bk-plotdiv" id="9118ac3a-d768-4f84-ba5a-ed613c07cfd2"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     var force = false;
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined" || force === true) {
#       window._bokeh_onload_callbacks = [];
#       window._bokeh_is_loading = undefined;
#     }
#
#
#
#     if (typeof (window._bokeh_timeout) === "undefined" || force === true) {
#       window._bokeh_timeout = Date.now() + 0;
#       window._bokeh_failed_load = false;
#     }
#
#     var NB_LOAD_WARNING = {'data': {'text/html':
#        "<div style='background-color: #fdd'>\n"+
#        "<p>\n"+
#        "BokehJS does not appear to have successfully loaded. If loading BokehJS from CDN, this \n"+
#        "may be due to a slow or bad network connection. Possible fixes:\n"+
#        "</p>\n"+
#        "<ul>\n"+
#        "<li>re-rerun `output_notebook()` to attempt to load from CDN again, or</li>\n"+
#        "<li>use INLINE resources instead, as so:</li>\n"+
#        "</ul>\n"+
#        "<code>\n"+
#        "from bokeh.resources import INLINE\n"+
#        "output_notebook(resources=INLINE)\n"+
#        "</code>\n"+
#        "</div>"}};
#
#     function display_loaded() {
#       if (window.Bokeh !== undefined) {
#         var el = document.getElementById("9118ac3a-d768-4f84-ba5a-ed613c07cfd2");
#         el.textContent = "BokehJS " + Bokeh.version + " successfully loaded.";
#       } else if (Date.now() < window._bokeh_timeout) {
#         setTimeout(display_loaded, 100)
#       }
#     }if ((window.Jupyter !== undefined) && Jupyter.notebook.kernel) {
#       comm_manager = Jupyter.notebook.kernel.comm_manager
#       comm_manager.register_target("2667de3e-d0e2-4672-ba83-e644527c911d", function () {});
#     }
#
#     function run_callbacks() {
#       try {
#         window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       }
#       finally {
#         delete window._bokeh_onload_callbacks
#       }
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("9118ac3a-d768-4f84-ba5a-ed613c07cfd2");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid '9118ac3a-d768-4f84-ba5a-ed613c07cfd2' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         (function() {
#           var fn = function() {
#             var docs_json = {"255175d3-451f-4995-bef1-9b3792eee311":{"roots":{"references":[{"attributes":{},"id":"8d191c23-3140-47ab-a110-0a8cc82a3967","type":"BasicTickFormatter"},{"attributes":{},"id":"01d15859-164e-4445-b00e-65b87cac4706","type":"LinearScale"},{"attributes":{},"id":"dcd11278-fd1e-4f1b-9303-cafbb0bfc738","type":"LinearScale"},{"attributes":{"plot":{"id":"e669f5a7-d41d-4e7a-b2fd-28f82046027a","subtype":"Figure","type":"Plot"}},"id":"5263e298-1819-455a-b335-9e303cf1eadf","type":"WheelZoomTool"},{"attributes":{"callback":null},"id":"cba2ac97-330c-433a-86f7-90054a720dad","type":"DataRange1d"},{"attributes":{"formatter":{"id":"963cda3a-2347-4f6c-9a10-40fda98e860e","type":"BasicTickFormatter"},"plot":{"id":"e669f5a7-d41d-4e7a-b2fd-28f82046027a","subtype":"Figure","type":"Plot"},"ticker":{"id":"648cf82f-c6bb-41bf-803c-98452887427a","type":"BasicTicker"}},"id":"36dcca09-09d9-4343-bf3a-57626eddf827","type":"LinearAxis"},{"attributes":{},"id":"b6921189-0b78-406a-b820-efa313fc489f","type":"BasicTicker"},{"attributes":{"formatter":{"id":"8d191c23-3140-47ab-a110-0a8cc82a3967","type":"BasicTickFormatter"},"plot":{"id":"e669f5a7-d41d-4e7a-b2fd-28f82046027a","subtype":"Figure","type":"Plot"},"ticker":{"id":"b6921189-0b78-406a-b820-efa313fc489f","type":"BasicTicker"}},"id":"254c3111-d68c-4517-931e-b0864a2552e3","type":"LinearAxis"},{"attributes":{"plot":{"id":"e669f5a7-d41d-4e7a-b2fd-28f82046027a","subtype":"Figure","type":"Plot"},"ticker":{"id":"b6921189-0b78-406a-b820-efa313fc489f","type":"BasicTicker"}},"id":"70c396c7-3d80-4797-bd6a-82370ae8a823","type":"Grid"},{"attributes":{"dimension":1,"plot":{"id":"e669f5a7-d41d-4e7a-b2fd-28f82046027a","subtype":"Figure","type":"Plot"},"ticker":{"id":"648cf82f-c6bb-41bf-803c-98452887427a","type":"BasicTicker"}},"id":"a8fa99ac-8433-4517-a990-0a8b67859170","type":"Grid"},{"attributes":{},"id":"648cf82f-c6bb-41bf-803c-98452887427a","type":"BasicTicker"},{"attributes":{"fill_color":{"value":"#1f77b4"},"line_color":{"value":"#1f77b4"},"size":{"units":"screen","value":20},"x":{"field":"x"},"y":{"field":"y"}},"id":"1212f10d-c67e-444f-9963-d8d3671f91d3","type":"Circle"},{"attributes":{"plot":{"id":"e669f5a7-d41d-4e7a-b2fd-28f82046027a","subtype":"Figure","type":"Plot"}},"id":"b46b4a98-7706-4049-9313-5dcad6554424","type":"HelpTool"},{"attributes":{"callback":null},"id":"d9ea0b2a-f890-41b0-88aa-310d5c00c2c1","type":"DataRange1d"},{"attributes":{"plot":{"id":"e669f5a7-d41d-4e7a-b2fd-28f82046027a","subtype":"Figure","type":"Plot"}},"id":"c392598d-49ed-4100-bbb7-c54784ec35ba","type":"ResetTool"},{"attributes":{},"id":"963cda3a-2347-4f6c-9a10-40fda98e860e","type":"BasicTickFormatter"},{"attributes":{"plot":{"id":"e669f5a7-d41d-4e7a-b2fd-28f82046027a","subtype":"Figure","type":"Plot"}},"id":"0ea1d627-3a81-44b6-89e3-ef3a09e0eb11","type":"SaveTool"},{"attributes":{"fill_alpha":{"value":0.1},"fill_color":{"value":"#1f77b4"},"line_alpha":{"value":0.1},"line_color":{"value":"#1f77b4"},"size":{"units":"screen","value":20},"x":{"field":"x"},"y":{"field":"y"}},"id":"05556239-ba0e-4b2e-9d70-a01d39e824ad","type":"Circle"},{"attributes":{"overlay":{"id":"8d941be6-078a-4f9e-8bcf-8accd84b5898","type":"BoxAnnotation"},"plot":{"id":"e669f5a7-d41d-4e7a-b2fd-28f82046027a","subtype":"Figure","type":"Plot"}},"id":"33661418-557e-47d5-abdd-ce5b625660b3","type":"BoxZoomTool"},{"attributes":{"callback":null,"column_names":["x","y"],"data":{"x":[1,2,3],"y":[4,5,6]}},"id":"e39df30a-4936-46ba-9dcc-9ecdafad8228","type":"ColumnDataSource"},{"attributes":{"active_drag":"auto","active_inspect":"auto","active_scroll":"auto","active_tap":"auto","tools":[{"id":"8eee2a3d-8745-4189-852d-7a77bfb5de2b","type":"PanTool"},{"id":"5263e298-1819-455a-b335-9e303cf1eadf","type":"WheelZoomTool"},{"id":"33661418-557e-47d5-abdd-ce5b625660b3","type":"BoxZoomTool"},{"id":"0ea1d627-3a81-44b6-89e3-ef3a09e0eb11","type":"SaveTool"},{"id":"c392598d-49ed-4100-bbb7-c54784ec35ba","type":"ResetTool"},{"id":"b46b4a98-7706-4049-9313-5dcad6554424","type":"H ...

# %%
# show which cell t2 handles
t2
# Out:
# <p><code>&lt;Bokeh Notebook handle for <strong>In[7]</strong>&gt;</code></p>

# %%
# this updates the immediately previous cell with an explicit handle
r3.glyph.fill_color = "orange"
push_notebook(handle=t2)

# %%
# this updates the left plot at the top with an explicit handle
r1.glyph.fill_color = "orange"
push_notebook(handle=t)

# %%
# get a handle to update the shown cell with
t3 = show(p2, notebook_handle=True)
# Out:
#     <div class="bk-root">
#         <div class="bk-plotdiv" id="b0ec54fc-b9bf-4c26-bb90-ad5220afc80f"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     var force = false;
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined" || force === true) {
#       window._bokeh_onload_callbacks = [];
#       window._bokeh_is_loading = undefined;
#     }
#
#
#
#     if (typeof (window._bokeh_timeout) === "undefined" || force === true) {
#       window._bokeh_timeout = Date.now() + 0;
#       window._bokeh_failed_load = false;
#     }
#
#     var NB_LOAD_WARNING = {'data': {'text/html':
#        "<div style='background-color: #fdd'>\n"+
#        "<p>\n"+
#        "BokehJS does not appear to have successfully loaded. If loading BokehJS from CDN, this \n"+
#        "may be due to a slow or bad network connection. Possible fixes:\n"+
#        "</p>\n"+
#        "<ul>\n"+
#        "<li>re-rerun `output_notebook()` to attempt to load from CDN again, or</li>\n"+
#        "<li>use INLINE resources instead, as so:</li>\n"+
#        "</ul>\n"+
#        "<code>\n"+
#        "from bokeh.resources import INLINE\n"+
#        "output_notebook(resources=INLINE)\n"+
#        "</code>\n"+
#        "</div>"}};
#
#     function display_loaded() {
#       if (window.Bokeh !== undefined) {
#         var el = document.getElementById("b0ec54fc-b9bf-4c26-bb90-ad5220afc80f");
#         el.textContent = "BokehJS " + Bokeh.version + " successfully loaded.";
#       } else if (Date.now() < window._bokeh_timeout) {
#         setTimeout(display_loaded, 100)
#       }
#     }if ((window.Jupyter !== undefined) && Jupyter.notebook.kernel) {
#       comm_manager = Jupyter.notebook.kernel.comm_manager
#       comm_manager.register_target("edebd939-b9fb-4ef6-a63a-42b39cd97ffa", function () {});
#     }
#
#     function run_callbacks() {
#       try {
#         window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       }
#       finally {
#         delete window._bokeh_onload_callbacks
#       }
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("b0ec54fc-b9bf-4c26-bb90-ad5220afc80f");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid 'b0ec54fc-b9bf-4c26-bb90-ad5220afc80f' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         (function() {
#           var fn = function() {
#             var docs_json = {"81b299b0-7247-4cc3-a545-10e61ded0654":{"roots":{"references":[{"attributes":{},"id":"c22f5393-c9db-4c0d-99b3-2d12632e8f7a","type":"BasicTicker"},{"attributes":{"formatter":{"id":"c8fd7e5c-883b-4c48-90d4-48ef3aaba4f1","type":"BasicTickFormatter"},"plot":{"id":"084a8104-a3eb-412f-b952-b3313c633b06","subtype":"Figure","type":"Plot"},"ticker":{"id":"c74be5f1-810a-4056-b3f8-d1ab81a17af3","type":"BasicTicker"}},"id":"bbd62d0e-0e1c-4505-94f5-029daba9897c","type":"LinearAxis"},{"attributes":{},"id":"c74be5f1-810a-4056-b3f8-d1ab81a17af3","type":"BasicTicker"},{"attributes":{"dimension":1,"plot":{"id":"084a8104-a3eb-412f-b952-b3313c633b06","subtype":"Figure","type":"Plot"},"ticker":{"id":"c74be5f1-810a-4056-b3f8-d1ab81a17af3","type":"BasicTicker"}},"id":"581be6dc-7b3a-48d8-b235-d8259605b75b","type":"Grid"},{"attributes":{"fill_alpha":{"value":0.1},"fill_color":{"value":"#1f77b4"},"line_alpha":{"value":0.1},"line_color":{"value":"#1f77b4"},"size":{"units":"screen","value":20},"x":{"field":"x"},"y":{"field":"y"}},"id":"34c8664e-843d-4b56-939f-498babf81122","type":"Circle"},{"attributes":{},"id":"2de709f0-2b5d-4608-9804-0e33c3bb973e","type":"BasicTickFormatter"},{"attributes":{"bottom_units":"screen","fill_alpha":{"value":0.5},"fill_color":{"value":"lightgrey"},"left_units":"screen","level":"overlay","line_alpha":{"value":1.0},"line_color":{"value":"black"},"line_dash":[4,4],"line_width":{"value":2},"plot":null,"render_mode":"css","right_units":"screen","top_units":"screen"},"id":"b7747a68-acc2-4260-8fdc-47d3cd7ddaa3","type":"BoxAnnotation"},{"attributes":{"plot":{"id":"084a8104-a3eb-412f-b952-b3313c633b06","subtype":"Figure","type":"Plot"}},"id":"de2d28cc-8a51-4892-b136-e249b9a02900","type":"PanTool"},{"attributes":{"plot":null,"text":""},"id":"8fc97459-f836-4906-b844-1f13455f7326","type":"Title"},{"attributes":{"plot":{"id":"084a8104-a3eb-412f-b952-b3313c633b06","subtype":"Figure","type":"Plot"}},"id":"9bfe4294-53d4-44f3-8a01-c68691e5c750","type":"WheelZoomTool"},{"attributes":{"overlay":{"id":"b7747a68-acc2-4260-8fdc-47d3cd7ddaa3","type":"BoxAnnotation"},"plot":{"id":"084a8104-a3eb-412f-b952-b3313c633b06","subtype":"Figure","type":"Plot"}},"id":"39a1306d-8922-45d8-8b75-01d167ff99d8","type":"BoxZoomTool"},{"attributes":{"plot":{"id":"084a8104-a3eb-412f-b952-b3313c633b06","subtype":"Figure","type":"Plot"}},"id":"0e79ef4b-c647-476b-935c-60be5b03680f","type":"SaveTool"},{"attributes":{"plot":{"id":"084a8104-a3eb-412f-b952-b3313c633b06","subtype":"Figure","type":"Plot"}},"id":"b1f8ba73-bf51-47d2-a579-0c74a81514d6","type":"ResetTool"},{"attributes":{"plot":{"id":"084a8104-a3eb-412f-b952-b3313c633b06","subtype":"Figure","type":"Plot"}},"id":"a5434e5b-7670-4cef-90ff-c45df5d0c896","type":"HelpTool"},{"attributes":{},"id":"c8fd7e5c-883b-4c48-90d4-48ef3aaba4f1","type":"BasicTickFormatter"},{"attributes":{"data_source":{"id":"8842315a-b53b-4ea7-bb0d-9bb3bd9a6391","type":"ColumnDataSource"},"glyph":{"id":"ebf00516-a503-4345-9f06-1c446d71614a","type":"Circle"},"hover_glyph":null,"muted_glyph":null,"nonselection_glyph":{"id":"34c8664e-843d-4b56-939f-498babf81122","type":"Circle"},"selection_glyph":null},"id":"a3481070-a305-4fb2-953e-b5b188058aea","type":"GlyphRenderer"},{"attributes":{"callback":null,"column_names":["x","y"],"data":{"x":[1,2,3],"y":[4,5,6]}},"id":"8842315a-b53b-4ea7-bb0d-9bb3bd9a6391","type":"ColumnDataSource"},{"attributes":{"callback":null},"id":"29c30191-6900-49a5-87f5-23dee5700c49","type":"DataRange1d"},{"attributes":{},"id":"81b90d53-b3f6-48ed-9883-fbbd463d4804","type":"ToolEvents"},{"attributes":{"active_drag":"auto","active_inspect":"auto","active_scroll":"auto","active_tap":"auto","tools":[{"id":"de2d28cc-8a51-4892-b136-e249b9a02900","type":"PanTool"},{"id":"9bfe4294-53d4-44f3-8a01-c68691e5c750","type":"WheelZoomTool"},{"id":"39a1306d-8922-45d8-8b75-01d167ff99d8","type":"BoxZoomTool"},{"id":"0e79ef4b-c647-476b-935c-60be5b03680f","type":"SaveTool"},{"id":"b1f8ba73-bf51-47d2-a579-0c74a81514d6","type ...

# %%
# this will update the immediately previous plot circle color because it was in the last shown cell
r2.glyph.fill_color = "red"
push_notebook()

# %%
# this will update the immediately previous plot circle color with an explicit handle
r2.glyph.fill_color = "blue"
push_notebook(handle=t3)
